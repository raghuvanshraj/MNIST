# %%
from data_loader import DataLoader

# %%
loader = DataLoader()

# %%
data = loader.load_data()

# %%
train_data = data[0]

# %%
test_data = data[1]

# %%
from network import Network

# %%
net = Network([784, 30, 10])

# %%
net.SGD(train_data, 10, 20, 0.05, test_data=test_data)
# Out:
# Epoch 0: 6563 / 10000
# Epoch 1: 6688 / 10000
# Epoch 2: 6620 / 10000
# Epoch 3: 6558 / 10000
# Epoch 4: 6606 / 10000
# Epoch 5: 6644 / 10000
# Epoch 6: 6700 / 10000
# Epoch 7: 6695 / 10000
# Epoch 8: 6663 / 10000
# Epoch 9: 6524 / 10000
