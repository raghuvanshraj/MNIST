# %%
from data_loader import DataLoader

# %%
loader = DataLoader()

# %%
data = loader.load_data()

# %%
train_data = data[0]

# %%
test_data = data[1]

# %%
from network import Network

# %%
net = Network([784, 30, 10])

# %%
net.load_network('network.pickle')

# %%
train_inputs = []
train_results = []
for x,y in train_data:
    train_inputs.append(x)
    train_results.append(y)

# %%
import numpy as np
results = [np.argmax(result) for result in train_results]

# %%
predictions = net.predict(train_inputs)

# %%
print(len(results), len(predictions))
# Out:
# 60000 60000

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(results, predictions)
# Out:
# 0.8870166666666667
