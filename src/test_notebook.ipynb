# %%
from data_loader import DataLoader

# %%
loader = DataLoader()

# %%
data = loader.load_data()

# %%
train_data = data[0]

# %%
train_images, train_labels = train_data[0], train_data[1]

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
train_labels.shape
# Out:
# (60000, 10)

# %%
counter = 0
for pixel in train_images[19]:
    counter += 1
    if pixel == 0:
        print('-', end='')
    else:
        print('@', end='')
        
    if counter % 28 == 0:
        print()
# Out:
# ----------------------------
# ----------------------------
# ----------------------------
# ----------------------------
# ----------------------------
# ----------------------------
# ----------------------------
# -------------@@@@@@---------
# ------------@@@@@@@@--------
# -----------@@@@@@@@@@-------
# -----------@@@---@@@@-------
# -----------@@@---@@@@-------
# -----------@@@@@@@@@--------
# -----------@@@@@@@----------
# -----------@@@@@@@----------
# ------------@@@@@-----------
# -------------@@@@-----------
# -------------@@@@-----------
# -------------@@@@-----------
# ------------@@@@------------
# -----------@@@@-------------
# -----------@@@--------------
# ----------@@@@--------------
# ---------@@@@---------------
# --------@@@@----------------
# --------@@@@----------------
# -------@@@@-----------------
# ----------------------------

# %%
train_images[0].shape
# Out:
# (784,)
