# %%
from data_loader import DataLoader

# %%
loader = DataLoader()

# %%
data = loader.load_data()

# %%
train_data = data[0]

# %%
test_data = data[1]

# %%
from network import Network

# %%
net = Network([784, 30, 10])

# %%
net.SGD(train_data, 10, 10, 0.0005, test_data=test_data)
# Out:
# Epoch 0: 8810 / 10000
# Epoch 1: 8812 / 10000
# Epoch 2: 8815 / 10000
# Epoch 3: 8815 / 10000
# Epoch 4: 8809 / 10000
# Epoch 5: 8805 / 10000
# Epoch 6: 8805 / 10000
# Epoch 7: 8805 / 10000
# Epoch 8: 8806 / 10000
# Epoch 9: 8805 / 10000

# %%
net.save_network('current_network.pickle')

# %%
net.load_network('network.pickle')

# %%
import sklearn

# %%
type(test_data)
# Out:
# list

# %%
test_inputs = []
test_results = []
for x,y in test_data:
    test_inputs.append(x)
    test_results.append(y)

# %%
test_inputs[0].shape
# Out:
# (784, 1)

# %%
predictions = net.predict(test_inputs)

# %%
predictions
# Out:
# [7,
#  2,
#  1,
#  0,
#  4,
#  1,
#  4,
#  9,
#  2,
#  7,
#  0,
#  6,
#  9,
#  0,
#  1,
#  5,
#  9,
#  7,
#  3,
#  4,
#  9,
#  6,
#  6,
#  5,
#  4,
#  0,
#  7,
#  4,
#  0,
#  1,
#  3,
#  1,
#  3,
#  6,
#  7,
#  2,
#  7,
#  1,
#  2,
#  1,
#  1,
#  7,
#  4,
#  1,
#  3,
#  5,
#  1,
#  2,
#  4,
#  4,
#  6,
#  3,
#  5,
#  5,
#  6,
#  0,
#  4,
#  1,
#  9,
#  5,
#  7,
#  2,
#  9,
#  2,
#  7,
#  9,
#  6,
#  4,
#  3,
#  0,
#  7,
#  0,
#  3,
#  7,
#  1,
#  7,
#  3,
#  7,
#  9,
#  7,
#  7,
#  6,
#  2,
#  7,
#  8,
#  4,
#  7,
#  3,
#  6,
#  1,
#  3,
#  6,
#  9,
#  3,
#  1,
#  4,
#  1,
#  7,
#  6,
#  9,
#  6,
#  0,
#  5,
#  4,
#  9,
#  9,
#  2,
#  1,
#  9,
#  4,
#  8,
#  7,
#  3,
#  9,
#  7,
#  4,
#  4,
#  4,
#  9,
#  6,
#  5,
#  6,
#  7,
#  6,
#  4,
#  9,
#  0,
#  5,
#  8,
#  5,
#  6,
#  6,
#  6,
#  7,
#  8,
#  1,
#  0,
#  1,
#  6,
#  4,
#  6,
#  7,
#  3,
#  1,
#  7,
#  1,
#  8,
#  2,
#  0,
#  9,
#  9,
#  9,
#  5,
#  5,
#  1,
#  5,
#  6,
#  0,
#  3,
#  4,
#  4,
#  6,
#  5,
#  4,
#  6,
#  5,
# ...

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_results, predictions, normalize=False)
# Out:
# 8805
